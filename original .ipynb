# %%
import pandas as pd
import numpy as np
fabab=pd.read_csv(r'C:\Users\MOJISOLA\Desktop\Data Analysis\170806005 R projects\assignment 2.csv')
print(fabab)
# Out:
#      Age  Height  No_of_cars Gender         Units Qualification
# 0     24    5.68           0      F   Gate keeper      Bsc/Beng
# 1     59    4.64           2      F       Drivers           OND
# 2     21    5.57           1      F     Engineers      Bsc/Beng
# 3     54    4.54           0      F   IT students           Msc
# 4     43    4.44           3      F      Cleaners          SSCE
# ..   ...     ...         ...    ...           ...           ...
# 115   36    5.68           2      F      Cleaners      Bsc/Beng
# 116   39    5.44           1      M  Data analyst          SSCE
# 117   56    4.53           0      F     Secretary      Bsc/Beng
# 118   22    4.99           3      F       Drivers          SSCE
# 119   21    4.17           1      F        Typist          SSCE
#
# [120 rows x 6 columns]

# %%
fabab.info() #to get full description of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            120 non-null    int64
#  1   Height         120 non-null    float64
#  2   No_of_cars     120 non-null    int64
#  3   Gender         120 non-null    object
#  4   Units          120 non-null    object
#  5   Qualification  120 non-null    object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 5.8+ KB

# %%
fabab.describe() #to get full description of the dataset
# Out:
#               Age      Height  No_of_cars
# count  120.000000  120.000000  120.000000
# mean    42.650000    4.879167    1.458333
# std     11.595167    0.561480    1.144191
# min     21.000000    4.060000    0.000000
# 25%     34.000000    4.375000    0.000000
# 50%     43.000000    4.770000    1.500000
# 75%     53.000000    5.352500    2.000000
# max     60.000000    5.980000    3.000000

# %%
fabab.head(10) #to show the first 10 data of the data frame
# Out:
#    Age  Height  No_of_cars Gender           Units Qualification
# 0   24    5.68           0      F     Gate keeper      Bsc/Beng
# 1   59    4.64           2      F         Drivers           OND
# 2   21    5.57           1      F       Engineers      Bsc/Beng
# 3   54    4.54           0      F     IT students           Msc
# 4   43    4.44           3      F        Cleaners          SSCE
# 5   34    5.03           3      F       Tech team           Msc
# 6   38    4.54           2      M      Accountant           Msc
# 7   53    4.36           2      F         HR team          SSCE
# 8   41    5.04           3      M  Factory worker           HND
# 9   41    5.13           3      F      Accountant           HND

# %%
fabab[['Age','Height']] #to select just age and height from the dataframe
# Out:
#      Age  Height
# 0     24    5.68
# 1     59    4.64
# 2     21    5.57
# 3     54    4.54
# 4     43    4.44
# ..   ...     ...
# 115   36    5.68
# 116   39    5.44
# 117   56    4.53
# 118   22    4.99
# 119   21    4.17
#
# [120 rows x 2 columns]

# %%
fabab[['Age','Units']]
# Out:
#      Age         Units
# 0     24   Gate keeper
# 1     59       Drivers
# 2     21     Engineers
# 3     54   IT students
# 4     43      Cleaners
# ..   ...           ...
# 115   36      Cleaners
# 116   39  Data analyst
# 117   56     Secretary
# 118   22       Drivers
# 119   21        Typist
#
# [120 rows x 2 columns]

# %%
fabab.groupby('Gender')['Qualification'].describe()
# Out:
#        count unique       top freq
# Gender
# F         57      5  Bsc/Beng   14
# M         63      5       Msc   16

# %%
fabab.groupby('Gender')['Age'].describe()
# Out:
#         count       mean        std   min   25%   50%   75%   max
# Gender
# F        57.0  43.824561  12.441467  21.0  35.0  44.0  55.0  60.0
# M        63.0  41.587302  10.762292  21.0  34.0  42.0  49.0  60.0

# %%
fabab.groupby('Age')['Qualification'].describe()
# Out:
#     count unique       top freq
# Age
# 21      5      3  Bsc/Beng    2
# 22      2      2       OND    1
# 23      1      1  Bsc/Beng    1
# 24      1      1  Bsc/Beng    1
# 26      7      4       HND    2
# 27      3      3  Bsc/Beng    1
# 29      2      2  Bsc/Beng    1
# 30      3      2       OND    2
# 31      1      1       Msc    1
# 32      1      1       OND    1
# 33      2      2       Msc    1
# 34      4      3       Msc    2
# 35      3      2       HND    2
# 36      1      1  Bsc/Beng    1
# 37      2      2       OND    1
# 38      2      2       Msc    1
# 39      3      2       Msc    2
# 40      5      4       Msc    2
# 41      4      3       HND    2
# 42      5      4       OND    2
# 43      5      2      SSCE    3
# 44      4      2       OND    3
# 45      5      3  Bsc/Beng    2
# 46      3      3       Msc    1
# 47      1      1      SSCE    1
# 48      4      4       HND    1
# 49      5      5      SSCE    1
# 50      1      1       OND    1
# ...

# %%
fabab[["Age","Height","No_of_cars"]].plot() #it shows the numerical values of height and number of cars are small , so small compared to age
# Out:
# <AxesSubplot:>

# %%
fabab[["Height","No_of_cars"]].plot()#it shows that highest value of cars stops at 3 and the height range from 4 to 6
# Out:
# <AxesSubplot:>

# %%
fabab=fabab.groupby(['Age']).sum()
fabab.sort_values("No_of_cars",ascending=False,inplace=True)
fabab.head(15)
# Out:
#      No_of_cars
# Age
# 79           11
# 96            9
# 42            8
# 41            7
# 179           6
# 117           6
# 83            6
# 33            6
# 43            6
# 57            6
# 46            5
# 84            5
# 80            5
# 65            5
# 60            5

# %%
fabab["Height"].plot.bar() #we can see we have more people between 4 and 5
# Out:
# <AxesSubplot:>

# %%
fabab[['Age','Height']].head(15).plot.bar(title="Age vs Height\n 2022",color=['g','red'])
#it plots age and height to show their spread
# Out:
# <AxesSubplot:title={'center':'Age vs Height\n 2022'}>

# %%
fabab["Age"].head(20).plot.pie(autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
fabab[["Age","Height"]].plot.box() #it shows how they cant be compared because age numerical values are more than the height numerical values
# Out:
# <AxesSubplot:>

# %%
fabab["No_of_cars"].plot.hist() #it shows that 0 is the most frequent of the data set
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
fabab.plot(kind='scatter',x='No_of_cars',y='Age',title='AGE VS NO OF CARS',s=0.9) #it shows there is no correlation
# Out:
# <AxesSubplot:title={'center':'AGE VS NO OF CARS'}, xlabel='No_of_cars', ylabel='Age'>

# %%
import seaborn as sns
sns.stripplot(x=fabab['Gender'],y=fabab['Age'],data=fabab)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Age'>

# %%
sns.stripplot(x=fabab['Qualification'],y=fabab['Age'],data=fabab, jitter=True)
# Out:
# <AxesSubplot:xlabel='Qualification', ylabel='Age'>

# %%
sns.stripplot(x='Gender',y='Age',hue='Qualification',data=fabab,jitter=True)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Age'>

# %%
sns.boxplot(x='Qualification',y='Age',hue='Gender',data=fabab,palette='Set3')
# Out:
# <AxesSubplot:xlabel='Qualification', ylabel='Age'>

# %%
sns.swarmplot(x='Qualification',y='Age',hue='Gender',data=fabab,palette='Set2',dodge=False)
# Out:
# <AxesSubplot:xlabel='Qualification', ylabel='Age'>

# %%
sns.jointplot(x='Qualification',y='Age',data=fabab)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set(style="whitegrid")
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='No_of_cars',y='Age', data=fabab, orient="v")

# %%
# %matplotlib inline

sns.set(style="whitegrid")
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Qualification',y='No_of_cars', data=fabab, orient="v")

# %%
filter_data = fabab.dropna(subset=['Age'])
plt.figure(figsize=(8,8))
sns.distplot(filter_data['Age'], kde=False)
# Out:
# C:\Users\MOJISOLA\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age'>

# %%
fabab.groupby(['Gender']).sum().plot(kind='pie', y='Height')
# Out:
# <AxesSubplot:ylabel='Height'>

# %%
pd.plotting.scatter_matrix(fabab)
# Out:
# array([[<AxesSubplot:xlabel='Age', ylabel='Age'>,
#         <AxesSubplot:xlabel='Height', ylabel='Age'>,
#         <AxesSubplot:xlabel='No_of_cars', ylabel='Age'>],
#        [<AxesSubplot:xlabel='Age', ylabel='Height'>,
#         <AxesSubplot:xlabel='Height', ylabel='Height'>,
#         <AxesSubplot:xlabel='No_of_cars', ylabel='Height'>],
#        [<AxesSubplot:xlabel='Age', ylabel='No_of_cars'>,
#         <AxesSubplot:xlabel='Height', ylabel='No_of_cars'>,
#         <AxesSubplot:xlabel='No_of_cars', ylabel='No_of_cars'>]],
#       dtype=object)
